# %%
import pandas as pd
import matplotlib.pyplot as plt

# Carica il tuo dataset CSV
dataset_path = 'smoking.csv'
df = pd.read_csv(dataset_path)

df = df[:10000]

# %%
# df = df.drop(['ID', 'height(cm)', 'oral'], axis=1)

df['tartar'] = df['tartar'].apply(lambda x: 1 if x == 'Y' else 0)
df['gender'] = df['gender'].apply(lambda x: 1 if x == 'M' else 0)
df['oral'] = df['oral'].apply(lambda x: 1 if x == 'Y' else 0)

# %%
import numpy as np
# Crea un istogramma e un boxplot per ogni colonna
for col in df.columns:
    # Istogramma
    plt.figure(figsize=(8, 6))
    plt.hist(df[col], bins=20, color='skyblue', edgecolor='black')
    plt.title(f'Istogramma di {col}')
    plt.xlabel(col)
    plt.ylabel('Frequenza')
    plt.show()

    # Genera valori casuali per l'asse x nell'intervallo [-1, 3]
    x_values = np.random.uniform(0, 2, size=len(df[col]))

    plt.figure(figsize=(10, 6), facecolor='white')  # Sfondo bianco

    # Boxplot con larghezza maggiore
    plt.boxplot(df[col], widths=1.5, patch_artist=True,  boxprops=dict(edgecolor=(1.0, 0.0, 1.0), facecolor='none', linewidth=2.5), medianprops=dict(color='red', linewidth=2.5))

    # Scatter plot con puntini neri
    plt.scatter(x_values, df[col], s=10, color='black', alpha=0.5)  # Puntini neri

    plt.title(f'Boxplot e scatter plot di {col}')
    plt.xlabel('X')
    plt.ylabel(col)
    plt.show()
